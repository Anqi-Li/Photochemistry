# %%
import xarray as xr
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
np.genfromtxt?

# %%
np.genfromtxt('/Users/anqili/Downloads/xsny.txt', unpack=True, skip_header=2)
# Out:
# array([[7.50e+00, 1.25e+01, 1.75e+01, ..., 8.40e+02, 8.45e+02, 8.50e+02],
#        [1.00e+09, 1.30e+09, 4.10e+09, ..., 2.13e+15, 2.09e+15, 2.05e+15],
#        [1.18e-18, 3.61e-18, 7.27e-18, ..., 0.00e+00, 0.00e+00, 0.00e+00],
#        [0.00e+00, 0.00e+00, 0.00e+00, ..., 1.40e-22, 1.42e-22, 1.45e-22],
#        [6.00e-19, 2.32e-18, 5.40e-18, ..., 0.00e+00, 0.00e+00, 0.00e+00],
#        [0.00e+00, 0.00e+00, 0.00e+00, ..., 0.00e+00, 0.00e+00, 0.00e+00]])

# %%
pd.read_csv('/Users/anqili/Downloads/xsny.txt',  header=[0,1])
# Out:
#       wave\t\t\tflux\t\t\txs O2\t\t\txs O3\t\t\txs N2\t\t\txs H2O
#     [nm]\t\t\t[cm-2s-1]\t\t[cm2]\t\t\t[cm2]\t\t\t[cm2]\t\t\t[cm2]
# 0    7.5000000e+00\t   1.0000000e+09\t   1.1800000e...
# 1    1.2500000e+01\t   1.3000000e+09\t   3.6100000e...
# 2    1.7500000e+01\t   4.1000000e+09\t   7.2700000e...
# 3    2.2500000e+01\t   4.8000000e+09\t   1.0500000e...
# 4    2.7500000e+01\t   7.5100000e+09\t   1.3650000e...
# 5    3.2500000e+01\t   4.3100000e+09\t   1.7950000e...
# 6    3.7500000e+01\t   1.5300000e+09\t   1.8170000e...
# 7    4.2500000e+01\t   1.0900000e+09\t   1.9390000e...
# 8    4.7500000e+01\t   1.2100000e+09\t   2.1590000e...
# 9    5.2500000e+01\t   1.2300000e+09\t   2.4060000e...
# 10   5.7500000e+01\t   8.7000000e+08\t   2.5040000e...
# 11   6.2500000e+01\t   9.6000000e+08\t   2.6020000e...
# 12   6.7500000e+01\t   4.5000000e+08\t   2.6270000e...
# 13   7.2500000e+01\t   3.4000000e+08\t   2.9050000e...
# 14   7.7500000e+01\t   1.8900000e+09\t   2.7090000e...
# ...
